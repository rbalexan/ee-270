# %% [markdown]
# ## Problem 1

# %%
using Images
using LinearAlgebra

# %%
img_path = "harvey-saturday-goes7am.jpg"
img = load(img_path)
size(img)
# Out:
# (1296, 1548)

# %%
X = Gray.(img)
# Out:
# 1296×1548 Array{Gray{N0f8},2} with eltype Gray{Normed{UInt8,8}}:
#  Gray{N0f8}(0.361)  Gray{N0f8}(0.349)  …  Gray{N0f8}(0.267)
#  Gray{N0f8}(0.349)  Gray{N0f8}(0.345)     Gray{N0f8}(0.271)
#  Gray{N0f8}(0.325)  Gray{N0f8}(0.333)     Gray{N0f8}(0.263)
#  Gray{N0f8}(0.31)   Gray{N0f8}(0.325)     Gray{N0f8}(0.259)
#  Gray{N0f8}(0.31)   Gray{N0f8}(0.329)     Gray{N0f8}(0.271)
#  Gray{N0f8}(0.275)  Gray{N0f8}(0.282)  …  Gray{N0f8}(0.267)
#  Gray{N0f8}(0.278)  Gray{N0f8}(0.271)     Gray{N0f8}(0.263)
#  Gray{N0f8}(0.286)  Gray{N0f8}(0.275)     Gray{N0f8}(0.255)
#  Gray{N0f8}(0.247)  Gray{N0f8}(0.259)     Gray{N0f8}(0.239)
#  Gray{N0f8}(0.251)  Gray{N0f8}(0.259)     Gray{N0f8}(0.231)
#  Gray{N0f8}(0.263)  Gray{N0f8}(0.263)  …  Gray{N0f8}(0.227)
#  Gray{N0f8}(0.247)  Gray{N0f8}(0.239)     Gray{N0f8}(0.227)
#  Gray{N0f8}(0.251)  Gray{N0f8}(0.259)     Gray{N0f8}(0.2)
#  ⋮                                     ⋱
#  Gray{N0f8}(0.404)  Gray{N0f8}(0.42)      Gray{N0f8}(0.431)
#  Gray{N0f8}(0.396)  Gray{N0f8}(0.408)  …  Gray{N0f8}(0.427)
#  Gray{N0f8}(0.435)  Gray{N0f8}(0.431)     Gray{N0f8}(0.424)
#  Gray{N0f8}(0.463)  Gray{N0f8}(0.447)     Gray{N0f8}(0.424)
#  Gray{N0f8}(0.439)  Gray{N0f8}(0.427)     Gray{N0f8}(0.42)
#  Gray{N0f8}(0.435)  Gray{N0f8}(0.435)     Gray{N0f8}(0.42)
#  Gray{N0f8}(0.451)  Gray{N0f8}(0.459)  …  Gray{N0f8}(0.416)
#  Gray{N0f8}(0.443)  Gray{N0f8}(0.463)     Gray{N0f8}(0.416)
#  Gray{N0f8}(0.447)  Gray{N0f8}(0.451)     Gray{N0f8}(0.412)
#  Gray{N0f8}(0.451)  Gray{N0f8}(0.459)     Gray{N0f8}(0.408)
#  Gray{N0f8}(0.439)  Gray{N0f8}(0.447)     Gray{N0f8}(0.412)
#  Gray{N0f8}(0.439)  Gray{N0f8}(0.447)  …  Gray{N0f8}(0.416)

# %%
X = Float64.(X);

# %%
function svd_compress(X, k)
    
    U, σ, V = svd(X, full=true); # slow to redo SVD, but not a big deal for homework
    X̃       = sum(σ[i] * U[:, i] * V[:, i]' for i in 1:k)
    err     = norm(X - X̃)/norm(X)
    
    return X̃, err
    
end
# Out:
# svd_compress (generic function with 1 method)

# %% [markdown]
# ### Problem 1a  |  $k = 2$

# %%
X̃, err = svd_compress(X, 2)
print(err)
Gray.(X̃)
# Out:
# 0.2815103158754801
# 1296×1548 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.37718)   Gray{Float64}(0.375673)  …  Gray{Float64}(0.329681)
#  Gray{Float64}(0.378822)  Gray{Float64}(0.377325)     Gray{Float64}(0.330979)
#  Gray{Float64}(0.381124)  Gray{Float64}(0.379679)     Gray{Float64}(0.332476)
#  Gray{Float64}(0.383908)  Gray{Float64}(0.382476)     Gray{Float64}(0.334706)
#  Gray{Float64}(0.382874)  Gray{Float64}(0.381406)     Gray{Float64}(0.334136)
#  Gray{Float64}(0.385124)  Gray{Float64}(0.383645)  …  Gray{Float64}(0.336127)
#  Gray{Float64}(0.38629)   Gray{Float64}(0.384753)     Gray{Float64}(0.337593)
#  Gray{Float64}(0.388017)  Gray{Float64}(0.386435)     Gray{Float64}(0.339417)
#  Gray{Float64}(0.38912)   Gray{Float64}(0.387497)     Gray{Float64}(0.340697)
#  Gray{Float64}(0.391091)  Gray{Float64}(0.389474)     Gray{Float64}(0.3423)
#  Gray{Float64}(0.393318)  Gray{Float64}(0.391721)  …  Gray{Float64}(0.344002)
#  Gray{Float64}(0.39345)   Gray{Float64}(0.391838)     Gray{Float64}(0.344245)
#  Gray{Float64}(0.39367)   Gray{Float64}(0.392046)     Gray{Float64}(0.344528)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.226813)  Gray{Float64}(0.226875)     Gray{Float64}(0.190075)
#  Gray{Float64}(0.225361)  Gray{Float64}(0.225404)  …  Gray{Float64}(0.189012)
#  Gray{Float64}(0.222973)  Gray{Float64}(0.222987)     Gray{Float64}(0.187251)
#  Gray{Float64}(0.220927)  Gray{Float64}(0.220915)     Gray{Float64}(0.18575)
#  Gray{Float64}(0.219739)  Gray{Float64}(0.21971)      Gray{Float64}(0.184899)
#  Gray{Float64}(0.219545)  Gray{Float64}(0.219521)     Gray{Float64}(0.184695)
#  Gray{Float64}(0.219524)  Gray{Float64}(0.219515)  …  Gray{Float64}(0.184552)
#  Gray{Float64}(0.219349)  Gray{Float64}(0.219344)     Gray{Float64}(0.184374)
#  Gray{Float64}(0.219709)  Gray{Float64}(0.219715)     Gray{Float64}(0.184583)
#  Gray{Float64}(0.219818)  Gray{Float64}(0.219852)     Gray{Float64}(0.184431)
#  Gray{Float64}(0.220079)  Gray{Float64}(0.220149)     Gray{Float64}(0.18435)
#  Gray{Float64}(0.220407)  Gray{Float64}(0.22051)   …  Gray{Float64}(0.18435)

# %% [markdown]
# ### Problem 1a  |  $k = 10$

# %%
X̃, err = svd_compress(X, 10)
print(err)
Gray.(X̃)
# Out:
# 0.15876586555633745
# 1296×1548 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.348307)  Gray{Float64}(0.351345)  …  Gray{Float64}(0.167435)
#  Gray{Float64}(0.349755)  Gray{Float64}(0.352983)     Gray{Float64}(0.174513)
#  Gray{Float64}(0.35093)   Gray{Float64}(0.354229)     Gray{Float64}(0.1774)
#  Gray{Float64}(0.353653)  Gray{Float64}(0.356967)     Gray{Float64}(0.183732)
#  Gray{Float64}(0.352005)  Gray{Float64}(0.355309)     Gray{Float64}(0.188064)
#  Gray{Float64}(0.355375)  Gray{Float64}(0.358714)  …  Gray{Float64}(0.193834)
#  Gray{Float64}(0.359701)  Gray{Float64}(0.3629)       Gray{Float64}(0.198949)
#  Gray{Float64}(0.361849)  Gray{Float64}(0.364861)     Gray{Float64}(0.203302)
#  Gray{Float64}(0.365742)  Gray{Float64}(0.368582)     Gray{Float64}(0.20804)
#  Gray{Float64}(0.369472)  Gray{Float64}(0.372303)     Gray{Float64}(0.212554)
#  Gray{Float64}(0.372922)  Gray{Float64}(0.375575)  …  Gray{Float64}(0.216192)
#  Gray{Float64}(0.372425)  Gray{Float64}(0.374906)     Gray{Float64}(0.215416)
#  Gray{Float64}(0.377813)  Gray{Float64}(0.379888)     Gray{Float64}(0.218133)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.414357)  Gray{Float64}(0.412493)     Gray{Float64}(0.469086)
#  Gray{Float64}(0.410451)  Gray{Float64}(0.40868)   …  Gray{Float64}(0.468081)
#  Gray{Float64}(0.404447)  Gray{Float64}(0.402748)     Gray{Float64}(0.464999)
#  Gray{Float64}(0.399198)  Gray{Float64}(0.397583)     Gray{Float64}(0.46237)
#  Gray{Float64}(0.395178)  Gray{Float64}(0.393688)     Gray{Float64}(0.459676)
#  Gray{Float64}(0.393284)  Gray{Float64}(0.391867)     Gray{Float64}(0.459254)
#  Gray{Float64}(0.391042)  Gray{Float64}(0.389736)  …  Gray{Float64}(0.457725)
#  Gray{Float64}(0.389394)  Gray{Float64}(0.388173)     Gray{Float64}(0.458134)
#  Gray{Float64}(0.388302)  Gray{Float64}(0.387115)     Gray{Float64}(0.459691)
#  Gray{Float64}(0.386253)  Gray{Float64}(0.385101)     Gray{Float64}(0.459102)
#  Gray{Float64}(0.384116)  Gray{Float64}(0.383061)     Gray{Float64}(0.458795)
#  Gray{Float64}(0.382315)  Gray{Float64}(0.381314)  …  Gray{Float64}(0.45811)

# %% [markdown]
# ### Problem 1a | $k = 40$

# %%
X̃, err = svd_compress(X, 40)
print(err)
Gray.(X̃)
# Out:
# 0.08368458635729387
# 1296×1548 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.347141)  Gray{Float64}(0.3495)    …  Gray{Float64}(0.177332)
#  Gray{Float64}(0.340383)  Gray{Float64}(0.344293)     Gray{Float64}(0.177261)
#  Gray{Float64}(0.330447)  Gray{Float64}(0.334924)     Gray{Float64}(0.179999)
#  Gray{Float64}(0.323384)  Gray{Float64}(0.329371)     Gray{Float64}(0.168986)
#  Gray{Float64}(0.316688)  Gray{Float64}(0.323569)     Gray{Float64}(0.169133)
#  Gray{Float64}(0.312863)  Gray{Float64}(0.320299)  …  Gray{Float64}(0.174699)
#  Gray{Float64}(0.315716)  Gray{Float64}(0.32395)      Gray{Float64}(0.16495)
#  Gray{Float64}(0.313675)  Gray{Float64}(0.321108)     Gray{Float64}(0.159109)
#  Gray{Float64}(0.30944)   Gray{Float64}(0.317573)     Gray{Float64}(0.156477)
#  Gray{Float64}(0.304979)  Gray{Float64}(0.312362)     Gray{Float64}(0.153273)
#  Gray{Float64}(0.307378)  Gray{Float64}(0.312692)  …  Gray{Float64}(0.158067)
#  Gray{Float64}(0.301013)  Gray{Float64}(0.30478)      Gray{Float64}(0.162925)
#  Gray{Float64}(0.294785)  Gray{Float64}(0.296364)     Gray{Float64}(0.16112)
#  ⋮                                                 ⋱
#  Gray{Float64}(0.450982)  Gray{Float64}(0.451671)     Gray{Float64}(0.414788)
#  Gray{Float64}(0.443411)  Gray{Float64}(0.444804)  …  Gray{Float64}(0.411256)
#  Gray{Float64}(0.434218)  Gray{Float64}(0.436335)     Gray{Float64}(0.40787)
#  Gray{Float64}(0.42819)   Gray{Float64}(0.430713)     Gray{Float64}(0.405427)
#  Gray{Float64}(0.425004)  Gray{Float64}(0.427947)     Gray{Float64}(0.401258)
#  Gray{Float64}(0.427082)  Gray{Float64}(0.430263)     Gray{Float64}(0.400454)
#  Gray{Float64}(0.432291)  Gray{Float64}(0.435434)  …  Gray{Float64}(0.397838)
#  Gray{Float64}(0.436237)  Gray{Float64}(0.439575)     Gray{Float64}(0.397187)
#  Gray{Float64}(0.438491)  Gray{Float64}(0.441775)     Gray{Float64}(0.401685)
#  Gray{Float64}(0.442509)  Gray{Float64}(0.44623)      Gray{Float64}(0.400472)
#  Gray{Float64}(0.442256)  Gray{Float64}(0.446233)     Gray{Float64}(0.399669)
#  Gray{Float64}(0.439801)  Gray{Float64}(0.444107)  …  Gray{Float64}(0.400262)

# %%
err_list = zeros(50)
U, σ, V = svd(X, full=true);
for (i, k) in enumerate(10 .^ range(0, stop=3, length=50))
    k = Int(floor(k))
    X̃           = zeros(size(X))
    X̃           = sum(σ[i] * U[:, i] * V[:, i]' for i in 1:k)
    err_list[i] = norm(X - X̃)/norm(X)
end

# %%
using Plots; pyplot()

plot(Int.(floor.(10 .^ range(0, stop=3, length=50))), err_list, 
        box=:on, thickness_scaling=1.1, yscale=:log10, label=:none,
        xlabel="Number of Singular Values",
        ylabel="Compression Error (||X-X̃||F / ||X||F)")

# %% [markdown]
# ## Problem 4

# %%
using MAT
using Statistics
# Out:
# ┌ Info: Precompiling MAT [23992714-dd62-5051-b70f-ba57cb901cac]
# └ @ Base loading.jl:1278

# %%
vars = matread("mnist_all.mat")
# Out:
# Dict{String,Any} with 20 entries:
#   "test7"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train3" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test6"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test2"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train7" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test3"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test5"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train2" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test1"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train9" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test9"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train8" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train5" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test0"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train0" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train1" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test4"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train6" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "train4" => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…
#   "test8"  => UInt8[0x00 0x00 … 0x00 0x00; 0x00 0x00 … 0x00 0x00; … ; 0x00 0x00…

# %%
img_as_mat = permutedims(reshape(vars["test3"][9,:], (28, 28)), [2, 1])
Gray.(img_as_mat/255)
# Out:
# 28×28 Array{Gray{Float64},2} with eltype Gray{Float64}:
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  ⋮                                       ⋱
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)  …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)
#  Gray{Float64}(0.0)  Gray{Float64}(0.0)     Gray{Float64}(0.0)

# %%
function get_dataset(vars, classifier_digit)

    X_train = zeros()
    y_train = zeros()

    X_test  = zeros()
    y_test  = zeros()

    for digit in 0:9

        label = digit == classifier_digit ? 1 : 0

        X_train = digit == 0 ? vars["train$(digit)"] : vcat(X_train, vars["train$(digit)"])
        y_train = digit == 0 ? label*ones(size(vars["train$(digit)"])[1], 1) : vcat(y_train, label*ones(size(vars["train$(digit)"])[1], 1))

        X_test  = digit == 0 ? vars["test$(digit)"]  : vcat(X_test,  vars["test$(digit)"])
        y_test  = digit == 0 ? label*ones(size(vars["test$(digit)"])[1], 1)  : vcat(y_test,  label*ones(size(vars["test$(digit)"])[1], 1))

    end

    X_train = Float64.(X_train)
    y_train = Float64.(y_train)

    X_test  = Float64.(X_test)
    y_test  = Float64.(y_test);
    
    return X_train, y_train, X_test, y_test
    
end
# Out:
# get_dataset (generic function with 1 method)

# %%
ws = []
accs = []
attention_maps = []

for digit in 0:9

    X_train, y_train, X_test, y_test = get_dataset(vars, digit)
    
    λ = 1E11
    w = inv(X_train'*X_train + λ*I)*X_train'*y_train
    
    push!(ws, w)
    
    y_pred = X_test * w

    y_pred[y_pred .<  0.5] .= 0
    y_pred[y_pred .>= 0.5] .= 1

    acc = mean(y_pred .== y_test)
    
    push!(accs, acc)
    
    w = abs.(w)
    w = (w .- minimum(w)) / (maximum(w) - minimum(w))
    attention_map = Gray.(permutedims(reshape(w, (28, 28)), [2, 1]))
    
    push!(attention_maps, attention_map)
    
end

accs
# Out:
# 10-element Array{Any,1}:
#  0.902
#  0.8865
#  0.8968
#  0.899
#  0.9018
#  0.9108
#  0.9042
#  0.8972
#  0.9026
#  0.8991

# %%
mosaicview(attention_maps..., nrow=1, rowmajor=true)
# Out:
# 28×280 MosaicView{Gray{Float64},4,PermutedDimsArray{Gray{Float64},4,(1, 2, 4, 3),(1, 2, 4, 3),Base.ReshapedArray{Gray{Float64},4,PaddedView{Gray{Float64},3,Tuple{Base.OneTo{Int64},Base.OneTo{Int64},Base.OneTo{Int64}},Array{Gray{Float64},3}},Tuple{Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64},Base.MultiplicativeInverses.SignedMultiplicativeInverse{Int64}}}}}:
#  Gray{Float64}(0.0)         …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)            Gray{Float64}(4.68424e-6)
#  Gray{Float64}(0.0)         …  Gray{Float64}(1.11192e-5)
#  Gray{Float64}(0.0)            Gray{Float64}(0.000121703)
#  Gray{Float64}(2.35785e-6)     Gray{Float64}(0.000140285)
#  Gray{Float64}(6.19419e-5)     Gray{Float64}(0.000119807)
#  Gray{Float64}(1.02523e-5)     Gray{Float64}(0.000115504)
#  Gray{Float64}(1.5605e-5)   …  Gray{Float64}(8.91823e-5)
#  Gray{Float64}(1.62492e-5)     Gray{Float64}(3.30235e-5)
#  Gray{Float64}(1.19384e-5)     Gray{Float64}(3.64516e-5)
#  ⋮                          ⋱
#  Gray{Float64}(2.66723e-6)     Gray{Float64}(3.504e-5)
#  Gray{Float64}(0.0)            Gray{Float64}(2.61806e-5)
#  Gray{Float64}(3.90635e-6)     Gray{Float64}(3.06055e-5)
#  Gray{Float64}(3.93026e-7)     Gray{Float64}(1.57356e-5)
#  Gray{Float64}(0.0)         …  Gray{Float64}(4.8002e-6)
#  Gray{Float64}(1.00457e-6)     Gray{Float64}(3.01225e-6)
#  Gray{Float64}(9.7318e-7)      Gray{Float64}(5.56107e-6)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)         …  Gray{Float64}(0.0)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0)
#  Gray{Float64}(0.0)            Gray{Float64}(0.0)

# %%
#attention_mat = rotl90(reshape(w, (28, 28)))
#heatmap(-attention_mat, c=:Spectral)

# %%
y_pred = X_test * w
scatter(y_pred, y_test)

# %%
y_pred = X_test * w
scatter(y_pred, y_test)

# %% [markdown]
# ## Problem 6

# %%
using Distributions

# %%
function rand_matrix_from_row_dist(dist, n, d)
    
    A = zeros(n, d)
    
    for i in 1:n
        A[i, :] = rand(dist)
    end
    
    return A
    
end

# %%
μ = ones(d)
Σ = [2*0.5^abs(i-j) for i in 1:d, j in 1:d]

μt = zeros(d)

GA = MvNormal(μ, Σ)
T1 = MvTDist(1, μt, Σ)
T3 = MvTDist(3, μt, Σ)

A_GA = rand_matrix_from_row_dist(GA, n, d)
A_T3 = rand_matrix_from_row_dist(T3, n, d)
A_T1 = rand_matrix_from_row_dist(T1, n, d);
